# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os,sys,warnings,random

import rasterio as rs
from rasterio.windows import Window,from_bounds
import geopandas as gpd

# %%
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import (
    BatchNormalization, Conv2D, Conv2DTranspose,
    MaxPooling2D, Dropout, Input, concatenate, Cropping2D,
    UpSampling2D
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.set_visible_devices(gpus[2:4], 'GPU')
logical_gpus = tf.config.list_logical_devices('GPU')
print(f'{len(gpus)}: Physical GPUs, {len(logical_gpus)}: Logical GPUs')
# Out:
# 4: Physical GPUs, 2: Logical GPUs

# %%
class fetch_geom_batch(keras.utils.Sequence):
    
    def __init__(self,patches_path:str,feature_image_path:str, label_image_path:str, label:str, img_size:tuple, batch_size:int):
        
        self.patches_path = patches_path
        self.feature_image_path = feature_image_path
        self.label_image_path = label_image_path
        self.label = label
        self.batch_size = batch_size
        self.img_size = img_size
        
        self.patches = gpd.read_file(self.patches_path)
        self.patches_label = self.patches[self.patches['label'] == self.label]
        self.patches_label_shuffle = self.patches_label.sample(frac=1)
        
        
    def __len__(self):
        return len(self.patches_label) // self.batch_size
    
    def __getitem__(self,idx):
        
        i = idx * self.batch_size
        geom_patch_batch = self.patches_label_shuffle.iloc[i : i + self.batch_size]
        
        
        feat_img = rs.open(self.feature_image_path)
        label_img = rs.open(self.label_image_path)

        image = np.zeros((self.batch_size,) + self.img_size + (9,), dtype="float32") # number of channel should be changed
        label = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="float32")
        
        for j, i in enumerate(range(len(geom_patch_batch))):
            minx,miny,maxx,maxy = geom_patch_batch.iloc[i, 3].bounds # Geometry column should be selected
            window_f = from_bounds(minx, miny, maxx, maxy, transform=feat_img.transform)
            window_l = from_bounds(minx, miny, maxx, maxy, transform=label_img.transform)
            transform = rs.transform.from_bounds(minx,miny,maxx,maxy, self.img_size[0], self.img_size[1])
            img_feat = np.moveaxis(feat_img.read(window=window_f,out_shape=self.img_size,resampling=0),0,2)
            img_label = np.moveaxis(label_img.read(window=window_l,out_shape=self.img_size,resampling=0),0,2)
            image[j] = img_feat
            label[j] = img_label
        
        return image, label[:,8:-8,8:-8,:]

# %%
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)  # -1 ultiplied as we want to minimize this value as loss function

# %%
# Constants
BATCH_SIZE = 32
EPOCHS = 30
IMAGE_SHAPE = (64, 64)
patches_path = './processed_DATA/patches_train_test_validation.geojson'
feature_image_path = "./processed_DATA/features.tif"
label_image_path = "./processed_DATA/binrized_image.tif"

# %%
filepath="./model/v2/weights-improvement-{epoch:02d}-{val_loss:.2f}.hdf5" #File name includes epoch and validation accuracy.
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

callbacks = [EarlyStopping(patience=20, monitor="val_loss"),checkpoint]

# %%
TRAINING_DATA = fetch_geom_batch(patches_path,feature_image_path,label_image_path,label='train',img_size=IMAGE_SHAPE,batch_size=BATCH_SIZE)
VALID_DATA = fetch_geom_batch(patches_path,feature_image_path,label_image_path,label='validation',img_size=IMAGE_SHAPE,batch_size=BATCH_SIZE)
TEST_DATA = fetch_geom_batch(patches_path,feature_image_path,label_image_path,label='test',img_size=IMAGE_SHAPE,batch_size=BATCH_SIZE)

# %%
def build_model(metrics: list,loss_function):
    inputs = tf.keras.layers.Input(shape=(64, 64, 9))
    
    # Encoder
    c1 = BatchNormalization(name='Norm1')(inputs)
    c1 = Conv2D(filters=16,kernel_size=(3,3),padding='valid', kernel_initializer='he_normal', activation='relu', name='Conv1_1')(c1)
    c1 = Conv2D(filters=32,kernel_size=(3,3),padding='valid', kernel_initializer='he_normal', activation='relu', name='Conv1_2')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = BatchNormalization(name='Norm2')(p1)
    c2 = Conv2D(filters=64,kernel_size=(3,3),padding='valid', kernel_initializer='he_normal', activation='relu', name='Conv2_1')(c2)
    c2 = Conv2D(filters=32,kernel_size=(3,3),padding='valid', kernel_initializer='he_normal', activation='relu', name='Conv2_2')(c2)
    
    u2 = UpSampling2D((2,2), name="up_dm1")(c2)
    u2 = concatenate([u2, Cropping2D(4)(c1)])
    c3 = Conv2D(filters=32,kernel_size=(3,3),padding='valid', kernel_initializer='he_normal', activation='relu', name='Conv3_1')(u2)
    c3 = Conv2D(filters=16,kernel_size=(3,3),padding='valid', kernel_initializer='he_normal', activation='relu', name='Conv3_2')(c3)
    
    output = keras.layers.Conv2D(filters=1,kernel_size=(3,3),padding='same', kernel_initializer='he_normal', activation='sigmoid', name='OutImage')(c3)
    model = tf.keras.Model(inputs, output,name='SARCNN')
    
    model.compile(optimizer='adam',
              loss= loss_function,
              metrics=metrics)
    return model


def run_model(metrics,loss):
    
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)
    
    model = build_model(metrics,loss)

    model_history = model.fit(TRAINING_DATA, epochs=EPOCHS,
                              validation_data=VALID_DATA,
                              use_multiprocessing=True,
                              workers=16,
                              max_queue_size=32,
                             callbacks=callbacks)
    
    return model, model_history

# %%
build_model(metrics=[jacard_coef,'accuracy'],loss_function= 'binary_crossentropy').summary()
# Out:
# Model: "SARCNN"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 9)]  0           []
#
#  Norm1 (BatchNormalization)     (None, 64, 64, 9)    36          ['input_2[0][0]']
#
#  Conv1_1 (Conv2D)               (None, 62, 62, 16)   1312        ['Norm1[0][0]']
#
#  Conv1_2 (Conv2D)               (None, 60, 60, 32)   4640        ['Conv1_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 30, 30, 32)  0           ['Conv1_2[0][0]']
#
#  Norm2 (BatchNormalization)     (None, 30, 30, 32)   128         ['max_pooling2d_1[0][0]']
#
#  Conv2_1 (Conv2D)               (None, 28, 28, 64)   18496       ['Norm2[0][0]']
#
#  Conv2_2 (Conv2D)               (None, 26, 26, 32)   18464       ['Conv2_1[0][0]']
#
#  up_dm1 (UpSampling2D)          (None, 52, 52, 32)   0           ['Conv2_2[0][0]']
#
#  cropping2d_1 (Cropping2D)      (None, 52, 52, 32)   0           ['Conv1_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 52, 52, 64)   0           ['up_dm1[0][0]',
#                                                                   'cropping2d_1[0][0]']
#
#  Conv3_1 (Conv2D)               (None, 50, 50, 32)   18464       ['concatenate_1[0][0]']
#
#  Conv3_2 (Conv2D)               (None, 48, 48, 16)   4624        ['Conv3_1[0][0]']
#
#  OutImage (Conv2D)              (None, 48, 48, 1)    145         ['Conv3_2[0][0]']
#
# ==================================================================================================
# Total params: 66,309
# Trainable params: 66,227
# Non-trainable params: 82
# __________________________________________________________________________________________________

# %%
model,model_history = run_model(metrics=[jacard_coef,'accuracy'],loss= 'binary_crossentropy')
# Out:
# Epoch 1/30
# 363/365 [============================>.] - ETA: 0s - loss: 0.2303 - jacard_coef: 0.1625 - accuracy: 0.9233
# Epoch 1: val_loss improved from inf to 0.24807, saving model to ./model/v2/weights-improvement-01-0.25.hdf5
# 365/365 [==============================] - 32s 77ms/step - loss: 0.2301 - jacard_coef: 0.1622 - accuracy: 0.9234 - val_loss: 0.2481 - val_jacard_coef: 0.0282 - val_accuracy: 0.9482
# Epoch 2/30
# 365/365 [==============================] - ETA: 0s - loss: 0.2031 - jacard_coef: 0.2162 - accuracy: 0.9316
# Epoch 2: val_loss improved from 0.24807 to 0.17581, saving model to ./model/v2/weights-improvement-02-0.18.hdf5
# 365/365 [==============================] - 29s 72ms/step - loss: 0.2031 - jacard_coef: 0.2162 - accuracy: 0.9316 - val_loss: 0.1758 - val_jacard_coef: 0.0928 - val_accuracy: 0.9474
# Epoch 3/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1943 - jacard_coef: 0.2351 - accuracy: 0.9342
# Epoch 3: val_loss improved from 0.17581 to 0.17004, saving model to ./model/v2/weights-improvement-03-0.17.hdf5
# 365/365 [==============================] - 31s 75ms/step - loss: 0.1943 - jacard_coef: 0.2351 - accuracy: 0.9342 - val_loss: 0.1700 - val_jacard_coef: 0.1000 - val_accuracy: 0.9484
# Epoch 4/30
# 364/365 [============================>.] - ETA: 0s - loss: 0.1897 - jacard_coef: 0.2466 - accuracy: 0.9353
# Epoch 4: val_loss did not improve from 0.17004
# 365/365 [==============================] - 29s 70ms/step - loss: 0.1896 - jacard_coef: 0.2463 - accuracy: 0.9353 - val_loss: 0.1775 - val_jacard_coef: 0.1033 - val_accuracy: 0.9440
# Epoch 5/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1858 - jacard_coef: 0.2551 - accuracy: 0.9366
# Epoch 5: val_loss did not improve from 0.17004
# 365/365 [==============================] - 28s 70ms/step - loss: 0.1858 - jacard_coef: 0.2551 - accuracy: 0.9366 - val_loss: 0.1880 - val_jacard_coef: 0.0841 - val_accuracy: 0.9497
# Epoch 6/30
# 363/365 [============================>.] - ETA: 0s - loss: 0.1851 - jacard_coef: 0.2574 - accuracy: 0.9369
# Epoch 6: val_loss improved from 0.17004 to 0.16788, saving model to ./model/v2/weights-improvement-06-0.17.hdf5
# 365/365 [==============================] - 29s 72ms/step - loss: 0.1852 - jacard_coef: 0.2581 - accuracy: 0.9368 - val_loss: 0.1679 - val_jacard_coef: 0.1167 - val_accuracy: 0.9477
# Epoch 7/30
# 363/365 [============================>.] - ETA: 0s - loss: 0.1825 - jacard_coef: 0.2644 - accuracy: 0.9375
# Epoch 7: val_loss did not improve from 0.16788
# 365/365 [==============================] - 29s 70ms/step - loss: 0.1821 - jacard_coef: 0.2646 - accuracy: 0.9377 - val_loss: 0.1692 - val_jacard_coef: 0.0947 - val_accuracy: 0.9499
# Epoch 8/30
# 364/365 [============================>.] - ETA: 0s - loss: 0.1798 - jacard_coef: 0.2714 - accuracy: 0.9384
# Epoch 8: val_loss improved from 0.16788 to 0.16317, saving model to ./model/v2/weights-improvement-08-0.16.hdf5
# 365/365 [==============================] - 29s 72ms/step - loss: 0.1797 - jacard_coef: 0.2713 - accuracy: 0.9384 - val_loss: 0.1632 - val_jacard_coef: 0.1016 - val_accuracy: 0.9495
# Epoch 9/30
# 362/365 [============================>.] - ETA: 0s - loss: 0.1783 - jacard_coef: 0.2746 - accuracy: 0.9389
# Epoch 9: val_loss improved from 0.16317 to 0.16288, saving model to ./model/v2/weights-improvement-09-0.16.hdf5
# 365/365 [==============================] - 30s 72ms/step - loss: 0.1784 - jacard_coef: 0.2745 - accuracy: 0.9388 - val_loss: 0.1629 - val_jacard_coef: 0.1167 - val_accuracy: 0.9489
# Epoch 10/30
# 364/365 [============================>.] - ETA: 0s - loss: 0.1757 - jacard_coef: 0.2789 - accuracy: 0.9394
# Epoch 10: val_loss did not improve from 0.16288
# 365/365 [==============================] - 29s 71ms/step - loss: 0.1756 - jacard_coef: 0.2791 - accuracy: 0.9394 - val_loss: 0.1730 - val_jacard_coef: 0.1146 - val_accuracy: 0.9455
# Epoch 11/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1756 - jacard_coef: 0.2812 - accuracy: 0.9397
# Epoch 11: val_loss did not improve from 0.16288
# 365/365 [==============================] - 30s 73ms/step - loss: 0.1756 - jacard_coef: 0.2812 - accuracy: 0.9397 - val_loss: 0.1705 - val_jacard_coef: 0.1196 - val_accuracy: 0.9449
# Epoch 12/30
# 360/365 [============================>.] - ETA: 0s - loss: 0.1733 - jacard_coef: 0.2864 - accuracy: 0.9400
# Epoch 12: val_loss did not improve from 0.16288
# 365/365 [==============================] - 29s 71ms/step - loss: 0.1731 - jacard_coef: 0.2858 - accuracy: 0.9400 - val_loss: 0.1665 - val_jacard_coef: 0.1070 - val_accuracy: 0.9495
# Epoch 13/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1714 - jacard_coef: 0.2897 - accuracy: 0.9405
# Epoch 13: val_loss did not improve from 0.16288
# 365/365 [==============================] - 30s 74ms/step - loss: 0.1714 - jacard_coef: 0.2897 - accuracy: 0.9405 - val_loss: 0.1632 - val_jacard_coef: 0.1064 - val_accuracy: 0.9493
# Epoch 14/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1699 - jacard_coef: 0.2937 - accuracy: 0.9411
# Epoch 14: val_loss improved from 0.16288 to 0.16024, saving model to ./model/v2/weights-improvement-14-0.16.hdf5
# 365/365 [==============================] - 30s 72ms/step - loss: 0.1699 - jacard_coef: 0.2937 - accuracy: 0.9411 - val_loss: 0.1602 - val_jacard_coef: 0.1168 - val_accuracy: 0.9498
# Epoch 15/30
# 363/365 [============================>.] - ETA: 0s - loss: 0.1687 - jacard_coef: 0.2970 - accuracy: 0.9414
# Epoch 15: val_loss did not improve from 0.16024
# 365/365 [==============================] - 30s 74ms/step - loss: 0.1687 - jacard_coef: 0.2969 - accuracy: 0.9414 - val_loss: 0.1677 - val_jacard_coef: 0.1206 - val_accuracy: 0.9460
# Epoch 16/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1673 - jacard_coef: 0.3007 - accuracy: 0.9420
# Epoch 16: val_loss did not improve from 0.16024
# 365/365 [==============================] - 31s 75ms/step - loss: 0.1673 - jacard_coef: 0.3007 - accuracy: 0.9420 - val_loss: 0.1667 - val_jacard_coef: 0.1096 - val_accuracy: 0.9495
# Epoch 17/30
# 364/365 [============================>.] - ETA: 0s - loss: 0.1661 - jacard_coef: 0.3033 - accuracy: 0.9422
# Epoch 17: val_loss did not improve from 0.16024
# 365/365 [==============================] - 31s 77ms/step - loss: 0.1662 - jacard_coef: 0.3033 - accuracy: 0.9422 - val_loss: 0.1765 - val_jacard_coef: 0.1025 - val_accuracy: 0.9500
# Epoch 18/30
# 363/365 [============================>.] - ETA: 0s - loss: 0.1646 - jacard_coef: 0.3059 - accuracy: 0.9427
# Epoch 18: val_loss did not improve from 0.16024
# 365/365 [==============================] - 31s 77ms/step - loss: 0.1647 - jacard_coef: 0.3063 - accuracy: 0.9426 - val_loss: 0.1660 - val_jacard_coef: 0.1146 - val_accuracy: 0.9497
# Epoch 19/30
# 364/365 [============================>.] - ETA: 0s - loss: 0.1632 - jacard_coef: 0.3113 - accuracy: 0.9432
# Epoch 19: val_loss did not improve from 0.16024
# 365/365 [==============================] - 30s 72ms/step - loss: 0.1634 - jacard_coef: 0.3111 - accuracy: 0.9431 - val_loss: 0.1693 - val_jacard_coef: 0.1194 - val_accuracy: 0.9465
# Epoch 20/30
# 362/365 [============================>.] - ETA: 0s - loss: 0.1616 - jacard_coef: 0.3149 - accuracy: 0.9437
# Epoch 20: val_loss did not improve from 0.16024
# 365/365 [==============================] - 29s 70ms/step - loss: 0.1614 - jacard_coef: 0.3145 - accuracy: 0.9437 - val_loss: 0.1684 - val_jacard_coef: 0.1142 - val_accuracy: 0.9496
# Epoch 21/30
# 362/365 [============================>.] - ETA: 0s - loss: 0.1609 - jacard_coef: 0.3151 - accuracy: 0.9439
# Epoch 21: val_loss did not improve from 0.16024
# 365/365 [==============================] - 31s 76ms/step - loss: 0.1609 - jacard_coef: 0.3157 - accuracy: 0.9438 - val_loss: 0.1709 - val_jacard_coef: 0.1290 - val_accuracy: 0.9441
# Epoch 22/30
# 363/365 [============================>.] - ETA: 0s - loss: 0.1589 - jacard_coef: 0.3216 - accuracy: 0.9443
# Epoch 22: val_loss did not improve from 0.16024
# 365/365 [==============================] - 31s 74ms/step - loss: 0.1588 - jacard_coef: 0.3213 - accuracy: 0.9443 - val_loss: 0.1692 - val_jacard_coef: 0.1209 - val_accuracy: 0.9456
# Epoch 23/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1587 - jacard_coef: 0.3224 - accuracy: 0.9446
# Epoch 23: val_loss did not improve from 0.16024
# 365/365 [==============================] - 30s 75ms/step - loss: 0.1587 - jacard_coef: 0.3224 - accuracy: 0.9446 - val_loss: 0.1855 - val_jacard_coef: 0.1183 - val_accuracy: 0.9385
# Epoch 24/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1574 - jacard_coef: 0.3264 - accuracy: 0.9451
# Epoch 24: val_loss did not improve from 0.16024
# 365/365 [==============================] - 30s 75ms/step - loss: 0.1574 - jacard_coef: 0.3264 - accuracy: 0.9451 - val_loss: 0.1625 - val_jacard_coef: 0.1222 - val_accuracy: 0.9496
# Epoch 25/30
# 360/365 [============================>.] - ETA: 0s - loss: 0.1561 - jacard_coef: 0.3291 - accuracy: 0.9454
# Epoch 25: val_loss did not improve from 0.16024
# 365/365 [==============================] - 31s 77ms/step - loss: 0.1558 - jacard_coef: 0.3297 - accuracy: 0.9455 - val_loss: 0.1770 - val_jacard_coef: 0.1306 - val_accuracy: 0.9440
# Epoch 26/30
# 360/365 [============================>.] - ETA: 0s - loss: 0.1546 - jacard_coef: 0.3349 - accuracy: 0.9460
# Epoch 26: val_loss did not improve from 0.16024
# 365/365 [==============================] - 29s 71ms/step - loss: 0.1543 - jacard_coef: 0.3344 - accuracy: 0.9461 - val_loss: 0.1696 - val_jacard_coef: 0.1262 - val_accuracy: 0.9481
# Epoch 27/30
# 364/365 [============================>.] - ETA: 0s - loss: 0.1540 - jacard_coef: 0.3355 - accuracy: 0.9462
# Epoch 27: val_loss did not improve from 0.16024
# 365/365 [==============================] - 30s 72ms/step - loss: 0.1539 - jacard_coef: 0.3353 - accuracy: 0.9462 - val_loss: 0.1728 - val_jacard_coef: 0.1256 - val_accuracy: 0.9446
# Epoch 28/30
# 363/365 [============================>.] - ETA: 0s - loss: 0.1534 - jacard_coef: 0.3380 - accuracy: 0.9465
# Epoch 28: val_loss did not improve from 0.16024
# 365/365 [==============================] - 31s 75ms/step - loss: 0.1534 - jacard_coef: 0.3375 - accuracy: 0.9465 - val_loss: 0.1686 - val_jacard_coef: 0.1331 - val_accuracy: 0.9464
# Epoch 29/30
# 363/365 [============================>.] - ETA: 0s - loss: 0.1515 - jacard_coef: 0.3425 - accuracy: 0.9470
# Epoch 29: val_loss did not improve from 0.16024
# 365/365 [==============================] - 30s 73ms/step - loss: 0.1515 - jacard_coef: 0.3425 - accuracy: 0.9470 - val_loss: 0.1674 - val_jacard_coef: 0.1245 - val_accuracy: 0.9466
# Epoch 30/30
# 365/365 [==============================] - ETA: 0s - loss: 0.1497 - jacard_coef: 0.3469 - accuracy: 0.9476
# Epoch 30: val_loss did not improve from 0.16024
# 365/365 [==============================] - 28s 68ms/step - loss: 0.1497 - jacard_coef: 0.3469 - accuracy: 0.9476 - val_loss: 0.1664 - val_jacard_coef: 0.1219 - val_accuracy: 0.9492

# %%
acc = model_history.history['accuracy']
val_acc = model_history.history['val_jacard_coef']

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(12, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Jacard Coef.')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
# plt.savefig('./foo.png')
plt.show()

# %%
# !ls ./model/v2
# Out:
# weights-improvement-01-0.25.hdf5  weights-improvement-08-0.16.hdf5
# weights-improvement-02-0.18.hdf5  weights-improvement-09-0.16.hdf5
# weights-improvement-03-0.17.hdf5  weights-improvement-14-0.16.hdf5
# weights-improvement-06-0.17.hdf5

# %%
best_model = keras.models.load_model('./model/v2/weights-improvement-14-0.16.hdf5',custom_objects={"jacard_coef":jacard_coef})

# %%
best_model.evaluate(TEST_DATA)
# Out:
# 201/201 [==============================] - 66s 324ms/step - loss: 0.2083 - jacard_coef: 0.1874 - accuracy: 0.9307
# [0.208322674036026, 0.18741092085838318, 0.9307262301445007]

# %%
randomlist = random.sample(range(0, 201), 30)
image = random.sample(range(0, 32), 1)

# %%
for i in randomlist:
    fig = plt.figure(1, figsize=([12, 12]))
    gs = plt.GridSpec(1,5, wspace=0.25, hspace=0.25)

    img_id = i
    feat, label = TEST_DATA[img_id]

    # Panel 01
    xtr_subsplot= fig.add_subplot(gs[:,:1])
    plt.imshow(feat[image[0],...,0])
    plt.title('SAR_VV_Before')

    # Panel 02
    xtr_subsplot= fig.add_subplot(gs[:,1:2])
    plt.imshow(feat[image[0],...,2])
    plt.title('SAR_VV_After')

    # Panel 03
    xtr_subsplot= fig.add_subplot(gs[:,2:3])
    plt.imshow(label[image[0],...,0])
    plt.title('Label')

    # Panel 04
    xtr_subsplot= fig.add_subplot(gs[:,3:4])
    plt.imshow(best_model.predict(feat[image[0],...].reshape(1,64,64,9))[0,...])
    plt.title('Predicted Probability')
    
    # Panel 04
    xtr_subsplot= fig.add_subplot(gs[:,4:])
    plt.imshow(np.where(best_model.predict(feat[image[0],...].reshape(1,64,64,9))[0,...]>0.3,1,0))
    plt.title('Predicted Label')


    plt.show()
